# %% [markdown]
# ### Working with Avro files
#
# Here are some examples of working with ZTF alerts stored as avro files.

# %%
import os
import io
import gzip
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from avro.datafile import DataFileReader, DataFileWriter
from avro.io import DatumReader, DatumWriter
import fastavro

from astropy.time import Time
from astropy.io import fits
import aplpy
# %matplotlib inline

# %% [markdown]
# A handful of sample alerts are available in the [ztf-avro-alert](https://github.com/ZwickyTransientFacility/ztf-avro-alert) repository, which also [documents](https://zwickytransientfacility.github.io/ztf-avro-alert/schema.html) the packet contents.

# %%
DATA_DIR = '~/Downloads/ztf_public_20201106/'

# %% [markdown]
# Let's count packets. Let's use a generator--we could eventually have millions of these alerts to look at!

# %%
def find_files(root_dir):
    for dir_name, subdir_list, file_list in os.walk(os.path.expanduser(root_dir), followlinks=True):
        for fname in file_list:
            if fname.endswith('.avro'):
                yield dir_name+'/'+fname

# %%
print('{} has {} avro files'.format(DATA_DIR, len(list(find_files(DATA_DIR)))))
# Out:
# ~/Downloads/ztf_public_20201106/ has 41374 avro files

# %% [markdown]
# Let's grab the first file and look at it

# %%
files_gen = find_files(DATA_DIR)
fname = next(files_gen)

# %%
fname
# Out:
# '/home/rostskadat/Downloads/ztf_public_20201106//1405470501015015011.avro'

# %% [markdown]
# Let's use the python `avro` library to see what's in the file.

# %%
# %%time
with open(fname,'rb') as f:
    freader = DataFileReader(f,DatumReader())
    for packet in freader:
        print(packet.keys())
# Out:
# dict_keys(['schemavsn', 'publisher', 'objectId', 'candid', 'candidate', 'prv_candidates', 'cutoutScience', 'cutoutTemplate', 'cutoutDifference'])
# CPU times: user 98.2 ms, sys: 564 µs, total: 98.8 ms
# Wall time: 98.4 ms

# %% [markdown]
# Now let's compare the call syntax of the faster `fastavro` package:

# %%
# %%time 
with open(fname,'rb') as f:
    freader = fastavro.reader(f)
    schema = freader.schema

    for packet in freader:
        print(packet.keys())
# Out:
# dict_keys(['schemavsn', 'publisher', 'objectId', 'candid', 'candidate', 'prv_candidates', 'cutoutScience', 'cutoutTemplate', 'cutoutDifference'])
# CPU times: user 5.69 ms, sys: 78 µs, total: 5.77 ms
# Wall time: 5.15 ms
# <timed exec>:3: DeprecationWarning: The 'schema' attribute is deprecated. Please use 'writer_schema'

# %% [markdown]
# Basically the same, and the latter is faster.  Here's the schema that was stored in the packet:

# %%
schema
# Out:
# {'doc': 'avro alert schema for ZTF (www.ztf.caltech.edu)',
#  'fields': [{'doc': 'schema version used',
#    'name': 'schemavsn',
#    'type': 'string'},
#   {'doc': 'origin of alert packet', 'name': 'publisher', 'type': 'string'},
#   {'doc': 'object identifier or name', 'name': 'objectId', 'type': 'string'},
#   {'name': 'candid', 'type': 'long'},
#   {'name': 'candidate',
#    'type': {'doc': 'avro alert schema',
#     'fields': [{'doc': 'Observation Julian date at start of exposure [days]',
#       'name': 'jd',
#       'type': 'double'},
#      {'doc': 'Filter ID (1=g; 2=R; 3=i)', 'name': 'fid', 'type': 'int'},
#      {'doc': 'Processing ID for science image to facilitate archive retrieval',
#       'name': 'pid',
#       'type': 'long'},
#      {'default': None,
#       'doc': 'Expected 5-sigma mag limit in difference image based on global noise estimate [mag]',
#       'name': 'diffmaglim',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'filename of positive (sci minus ref) difference image',
#       'name': 'pdiffimfilename',
#       'type': ['null', 'string']},
#      {'default': None,
#       'doc': 'Principal investigator attached to program ID',
#       'name': 'programpi',
#       'type': ['null', 'string']},
#      {'doc': 'Program ID: encodes either public, collab, or caltech mode',
#       'name': 'programid',
#       'type': 'int'},
#      {'doc': 'Candidate ID from operations DB',
#       'name': 'candid',
#       'type': 'long'},
#      {'doc': 't or 1 => candidate is from positive (sci minus ref) subtraction; f or 0 => candidate is from negative (ref minus sci) subtraction',
#       'name': 'isdiffpos',
#       'type': 'string'},
#      {'default': None,
#       'doc': 'Internal pipeline table extraction ID',
#       'name': 'tblid',
#       'type': ['null', 'long']},
#      {'default': None,
#       'doc': 'Night ID',
#       'name': 'nid',
#       'type': ['null', 'int']},
#      {'default': None,
#       'doc': 'Readout channel ID [00 .. 63]',
#       'name': 'rcid',
#       'type': ['null', 'int']},
#      {'default': None,
#       'doc': 'ZTF field ID',
#       'name': 'field',
#       'type': ['null', 'int']},
#      {'default': None,
#       'doc': 'x-image position of candidate [pixels]',
#       'name': 'xpos',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'y-image position of candidate [pixels]',
#       'name': 'ypos',
#       'type': ['null', 'float']},
#      {'doc': 'Right Ascension of candidate; J2000 [deg]',
#       'name': 'ra',
#       'type': 'double'},
#      {'doc': 'Declination of candidate; J2000 [deg]',
#       'name': 'dec',
#       'type': 'double'},
#      {'doc': 'Magnitude from PSF-fit photometry [mag]',
#       'name': 'magpsf',
#       'type': 'float'},
#      {'doc': '1-sigma uncertainty in magpsf [mag]',
#       'name': 'sigmapsf',
#       'type': 'float'},
#      {'default': None,
#       'doc': 'Reduced chi-square for PSF-fit',
#       'name': 'chipsf',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Aperture mag using 14 pixel diameter aperture [mag]',
#       'name': 'magap',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': '1-sigma uncertainty in magap [mag]',
#       'name': 'sigmagap',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'distance to nearest source in reference image PSF-catalog [pixels]',
#       'name': 'distnr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'magnitude of nearest source in reference image PSF-catalog [mag]',
#       'name': 'magnr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': '1-sigma uncertainty in magnr [mag]',
#       'name': 'sigmagnr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'DAOPhot chi parameter of nearest source in reference image PSF-catalog',
#       'name': 'chinr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'DAOPhot sharp parameter of nearest source in reference image PSF-catalog',
#       'name': 'sharpnr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Local sky background estimate [DN]',
#       'name': 'sky',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Difference: magap - magpsf [mag]',
#       'name': 'magdiff',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Full Width Half Max assuming a Gaussian core, from SExtractor [pixels]',
#       'name': 'fwhm',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Star/Galaxy classification score from SExtractor',
#       'name': 'classtar',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Distance to nearest edge in image [pixels]',
#       'name': 'mindtoedge',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Difference: diffmaglim - magap [mag]',
#       'name': 'magfromlim',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Ratio: difffwhm / fwhm',
#       'name': 'seeratio',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Windowed profile RMS afloat major axis from SExtractor [pixels]',
#       'name': 'aimage',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Windowed profile RMS afloat minor axis from SExtractor [pixels]',
#       'name': 'bimage',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Ratio: aimage / fwhm',
#       'name': 'aimagerat',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Ratio: bimage / fwhm',
#       'name': 'bimagerat',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Ratio: aimage / bimage',
#       'name': 'elong',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'number of negative pixels in a 5 x 5 pixel stamp',
#       'name': 'nneg',
#       'type': ['null', 'int']},
#      {'default': None,
#       'doc': 'number of prior-tagged bad pixels in a 5 x 5 pixel stamp',
#       'name': 'nbad',
#       'type': ['null', 'int']},
#      {'default': None,
#       'doc': 'RealBogus quality score from Random Forest classifier; range is 0 to 1 where closer to 1 is more reliable',
#       'name': 'rb',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'distance to nearest known solar system object if exists within 30 arcsec [arcsec]',
#       'name': 'ssdistnr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'magnitude of nearest known solar system object if exists within 30 arcsec (usually V-band from MPC archive) [mag]',
#       'name': 'ssmagnr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'name of nearest known solar system object if exists within 30 arcsec (from MPC archive)',
#       'name': 'ssnamenr',
#       'type': ['null', 'string']},
#      {'default': None,
#       'doc': 'Ratio: sum(pixels) / sum(|pixels|) in a 5 x 5 pixel stamp where stamp is first median-filtered to mitigate outliers',
#       'name': 'sumrat',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Aperture mag using 18 pixel diameter aperture [mag]',
#       'name': 'magapbig',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': '1-sigma uncertainty in magapbig [mag]',
#       'name': 'sigmagapbig',
#       'type': ['null', 'float']},
#      {'doc': 'Right Ascension of nearest source in reference image PSF-catalog; J2000 [deg]',
#       'name': 'ranr',
#       'type': 'double'},
#      {'doc': 'Declination of nearest source in reference image PSF-catalog; J2000 [deg]',
#       'name': 'decnr',
#       'type': 'double'},
#      {'default': None,
#       'doc': 'g-band PSF-fit magnitude of closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#       'name': 'sgmag1',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'r-band PSF-fit magnitude of closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#       'name': 'srmag1',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'i-band PSF-fit magnitude of closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#       'name': 'simag1',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'z-band PSF-fit magnitude of closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#       'name': 'szmag1',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Star/Galaxy score of closest source from PS1 catalog; if exists within 30 arcsec: 0 <= sgscore <= 1 where closer to 1 implies higher likelihood of being a star',
#       'name': 'sgscore1',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Distance to closest source from PS1 catalog; if exists within 30 arcsec [arcsec]',
#       'name': 'distpsnr1',
#       'type': ['null', 'float']},
#      {'doc': 'Number of spatially-coincident detections falling within 1.5 arcsec going back to beginning of survey; only detections that fell on the same field and readout-channel ID where the input candidate was observed are counted',
#       'name': 'ndethist',
#       'type': 'int'},
#      {'doc': 'Number of times input candidate position fell on any field and readout-channel going back to beginning of survey',
#       'name': 'ncovhist',
#       'type': 'int'},
#      {'default': None,
#       'doc': 'Earliest Julian date of epoch corresponding to ndethist [days]',
#       'name': 'jdstarthist',
#       'type': ['null', 'double']},
#      {'default': None,
#       'doc': 'Latest Julian date of epoch corresponding to ndethist [days]',
#       'name': 'jdendhist',
#       'type': ['null', 'double']},
#      {'default': None,
#       'doc': 'Peak-pixel signal-to-noise ratio in point source matched-filtered detection image',
#       'name': 'scorr',
#       'type': ['null', 'double']},
#      {'default': 0,
#       'doc': '1 => candidate is from a Target-of-Opportunity (ToO) exposure; 0 => candidate is from a non-ToO exposure',
#       'name': 'tooflag',
#       'type': ['null', 'int']},
#      {'default': None,
#       'doc': 'Object ID of closest source from PS1 catalog; if exists within 30 arcsec',
#       'name': 'objectidps1',
#       'type': ['null', 'long']},
#      {'default': None,
#       'doc': 'Object ID of second closest source from PS1 catalog; if exists within 30 arcsec',
#       'name': 'objectidps2',
#       'type': ['null', 'long']},
#      {'default': None,
#       'doc': 'g-band PSF-fit magnitude of second closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#       'name': 'sgmag2',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'r-band PSF-fit magnitude of second closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#       'name': 'srmag2',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'i-band PSF-fit magnitude of second closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#       'name': 'simag2',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'z-band PSF-fit magnitude of second closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#       'name': 'szmag2',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Star/Galaxy score of second closest source from PS1 catalog; if exists within 30 arcsec: 0 <= sgscore <= 1 where closer to 1 implies higher likelihood of being a star',
#       'name': 'sgscore2',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Distance to second closest source from PS1 catalog; if exists within 30 arcsec [arcsec]',
#       'name': 'distpsnr2',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Object ID of third closest source from PS1 catalog; if exists within 30 arcsec',
#       'name': 'objectidps3',
#       'type': ['null', 'long']},
#      {'default': None,
#       'doc': 'g-band PSF-fit magnitude of third closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#       'name': 'sgmag3',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'r-band PSF-fit magnitude of third closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#       'name': 'srmag3',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'i-band PSF-fit magnitude of third closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#       'name': 'simag3',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'z-band PSF-fit magnitude of third closest source from PS1 catalog; if exists within 30 arcsec [mag]',
#       'name': 'szmag3',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Star/Galaxy score of third closest source from PS1 catalog; if exists within 30 arcsec: 0 <= sgscore <= 1 where closer to 1 implies higher likelihood of being a star',
#       'name': 'sgscore3',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Distance to third closest source from PS1 catalog; if exists within 30 arcsec [arcsec]',
#       'name': 'distpsnr3',
#       'type': ['null', 'float']},
#      {'doc': 'Number of source matches from PS1 catalog falling within 30 arcsec',
#       'name': 'nmtchps',
#       'type': 'int'},
#      {'doc': 'Processing ID for reference image to facilitate archive retrieval',
#       'name': 'rfid',
#       'type': 'long'},
#      {'doc': 'Observation Julian date of earliest exposure used to generate reference image [days]',
#       'name': 'jdstartref',
#       'type': 'double'},
#      {'doc': 'Observation Julian date of latest exposure used to generate reference image [days]',
#       'name': 'jdendref',
#       'type': 'double'},
#      {'doc': 'Number of frames (epochal images) used to generate reference image',
#       'name': 'nframesref',
#       'type': 'int'},
#      {'doc': 'version of Random Forest classifier model used to assign RealBogus (rb) quality score',
#       'name': 'rbversion',
#       'type': 'string'},
#      {'default': None,
#       'doc': 'Ratio: D/stddev(D) on event position where D = difference image',
#       'name': 'dsnrms',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Ratio: S/stddev(S) on event position where S = image of convolution: D (x) PSF(D)',
#       'name': 'ssnrms',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Difference of statistics: dsnrms - ssnrms',
#       'name': 'dsdiff',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Magnitude zero point for photometry estimates [mag]',
#       'name': 'magzpsci',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Magnitude zero point uncertainty (in magzpsci) [mag]',
#       'name': 'magzpsciunc',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'RMS (deviation from average) in all differences between instrumental photometry and matched photometric calibrators from science image processing [mag]',
#       'name': 'magzpscirms',
#       'type': ['null', 'float']},
#      {'doc': 'Number of PS1 photometric calibrators used to calibrate science image from science image processing',
#       'name': 'nmatches',
#       'type': 'int'},
#      {'default': None,
#       'doc': 'Color coefficient from linear fit from photometric calibration of science image',
#       'name': 'clrcoeff',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Color coefficient uncertainty from linear fit (corresponding to clrcoeff)',
#       'name': 'clrcounc',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance in magzpsci and clrcoeff from science image processing [mag^2]',
#       'name': 'zpclrcov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Magnitude zero point from median of all differences between instrumental photometry and matched photometric calibrators from science image processing [mag]',
#       'name': 'zpmed',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Median color of all PS1 photometric calibrators used from science image processing [mag]: for filter (fid) = 1, 2, 3, PS1 color used = g-r, g-r, r-i respectively',
#       'name': 'clrmed',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'RMS color (deviation from average) of all PS1 photometric calibrators used from science image processing [mag]',
#       'name': 'clrrms',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Distance to closest source from Gaia DR1 catalog irrespective of magnitude; if exists within 90 arcsec [arcsec]',
#       'name': 'neargaia',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Distance to closest source from Gaia DR1 catalog brighter than magnitude 14; if exists within 90 arcsec [arcsec]',
#       'name': 'neargaiabright',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Gaia (G-band) magnitude of closest source from Gaia DR1 catalog irrespective of magnitude; if exists within 90 arcsec [mag]',
#       'name': 'maggaia',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Gaia (G-band) magnitude of closest source from Gaia DR1 catalog brighter than magnitude 14; if exists within 90 arcsec [mag]',
#       'name': 'maggaiabright',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Integration time of camera exposure [sec]',
#       'name': 'exptime',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'RealBogus quality score from Deep-Learning-based classifier; range is 0 to 1 where closer to 1 is more reliable',
#       'name': 'drb',
#       'type': ['null', 'float']},
#      {'doc': 'version of Deep-Learning-based classifier model used to assign RealBogus (drb) quality score',
#       'name': 'drbversion',
#       'type': 'string'}],
#     'name': 'candidate',
#     'namespace': 'ztf.alert',
#     'type': 'record',
#     'version': '3.3'}},
#   {'default': None,
#    'name': 'prv_candidates',
#    'type': ['null',
#     {'items': {'doc': 'avro alert schema',
#       'fields': [{'doc': 'Observation Julian date at start of exposure [days]',
#         'name': 'jd',
#         'type': 'double'},
#        {'doc': 'Filter ID (1=g; 2=R; 3=i)', 'name': 'fid', 'type': 'int'},
#        {'doc': 'Processing ID for image', 'name': 'pid', 'type': 'long'},
#        {'default': None,
#         'doc': 'Expected 5-sigma mag limit in difference image based on global noise estimate [mag]',
#         'name': 'diffmaglim',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'filename of positive (sci minus ref) difference image',
#         'name': 'pdiffimfilename',
#         'type': ['null', 'string']},
#        {'default': None,
#         'doc': 'Principal investigator attached to program ID',
#         'name': 'programpi',
#         'type': ['null', 'string']},
#        {'doc': 'Program ID: encodes either public, collab, or caltech mode',
#         'name': 'programid',
#         'type': 'int'},
#        {'doc': 'Candidate ID from operations DB',
#         'name': 'candid',
#         'type': ['null', 'long']},
#        {'doc': 't or 1 => candidate is from positive (sci minus ref) subtraction; f or 0 => candidate is from negative (ref minus sci) subtraction',
#         'name': 'isdiffpos',
#         'type': ['null', 'string']},
#        {'default': None,
#         'doc': 'Internal pipeline table extraction ID',
#         'name': 'tblid',
#         'type': ['null', 'long']},
#        {'default': None,
#         'doc': 'Night ID',
#         'name': 'nid',
#         'type': ['null', 'int']},
#        {'default': None,
#         'doc': 'Readout channel ID [00 .. 63]',
#         'name': 'rcid',
#         'type': ['null', 'int']},
#        {'default': None,
#         'doc': 'ZTF field ID',
#         'name': 'field',
#         'type': ['null', 'int']},
#        {'default': None,
#         'doc': 'x-image position of candidate [pixels]',
#         'name': 'xpos',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'y-image position of candidate [pixels]',
#         'name': 'ypos',
#         'type': ['null', 'float']},
#        {'doc': 'Right Ascension of candidate; J2000 [deg]',
#         'name': 'ra',
#         'type': ['null', 'double']},
#        {'doc': 'Declination of candidate; J2000 [deg]',
#         'name': 'dec',
#         'type': ['null', 'double']},
#        {'doc': 'Magnitude from PSF-fit photometry [mag]',
#         'name': 'magpsf',
#         'type': ['null', 'float']},
#        {'doc': '1-sigma uncertainty in magpsf [mag]',
#         'name': 'sigmapsf',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Reduced chi-square for PSF-fit',
#         'name': 'chipsf',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Aperture mag using 14 pixel diameter aperture [mag]',
#         'name': 'magap',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': '1-sigma uncertainty in magap [mag]',
#         'name': 'sigmagap',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'distance to nearest source in reference image PSF-catalog [pixels]',
#         'name': 'distnr',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'magnitude of nearest source in reference image PSF-catalog [mag]',
#         'name': 'magnr',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': '1-sigma uncertainty in magnr [mag]',
#         'name': 'sigmagnr',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'DAOPhot chi parameter of nearest source in reference image PSF-catalog',
#         'name': 'chinr',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'DAOPhot sharp parameter of nearest source in reference image PSF-catalog',
#         'name': 'sharpnr',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Local sky background estimate [DN]',
#         'name': 'sky',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Difference: magap - magpsf [mag]',
#         'name': 'magdiff',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Full Width Half Max assuming a Gaussian core, from SExtractor [pixels]',
#         'name': 'fwhm',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Star/Galaxy classification score from SExtractor',
#         'name': 'classtar',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Distance to nearest edge in image [pixels]',
#         'name': 'mindtoedge',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Difference: diffmaglim - magap [mag]',
#         'name': 'magfromlim',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Ratio: difffwhm / fwhm',
#         'name': 'seeratio',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Windowed profile RMS afloat major axis from SExtractor [pixels]',
#         'name': 'aimage',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Windowed profile RMS afloat minor axis from SExtractor [pixels]',
#         'name': 'bimage',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Ratio: aimage / fwhm',
#         'name': 'aimagerat',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Ratio: bimage / fwhm',
#         'name': 'bimagerat',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Ratio: aimage / bimage',
#         'name': 'elong',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'number of negative pixels in a 5 x 5 pixel stamp',
#         'name': 'nneg',
#         'type': ['null', 'int']},
#        {'default': None,
#         'doc': 'number of prior-tagged bad pixels in a 5 x 5 pixel stamp',
#         'name': 'nbad',
#         'type': ['null', 'int']},
#        {'default': None,
#         'doc': 'RealBogus quality score; range is 0 to 1 where closer to 1 is more reliable',
#         'name': 'rb',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'distance to nearest known solar system object if exists within 30 arcsec [arcsec]',
#         'name': 'ssdistnr',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'magnitude of nearest known solar system object if exists within 30 arcsec (usually V-band from MPC archive) [mag]',
#         'name': 'ssmagnr',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'name of nearest known solar system object if exists within 30 arcsec (from MPC archive)',
#         'name': 'ssnamenr',
#         'type': ['null', 'string']},
#        {'default': None,
#         'doc': 'Ratio: sum(pixels) / sum(|pixels|) in a 5 x 5 pixel stamp where stamp is first median-filtered to mitigate outliers',
#         'name': 'sumrat',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Aperture mag using 18 pixel diameter aperture [mag]',
#         'name': 'magapbig',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': '1-sigma uncertainty in magapbig [mag]',
#         'name': 'sigmagapbig',
#         'type': ['null', 'float']},
#        {'doc': 'Right Ascension of nearest source in reference image PSF-catalog; J2000 [deg]',
#         'name': 'ranr',
#         'type': ['null', 'double']},
#        {'doc': 'Declination of nearest source in reference image PSF-catalog; J2000 [deg]',
#         'name': 'decnr',
#         'type': ['null', 'double']},
#        {'default': None,
#         'doc': 'Peak-pixel signal-to-noise ratio in point source matched-filtered detection image',
#         'name': 'scorr',
#         'type': ['null', 'double']},
#        {'default': None,
#         'doc': 'Magnitude zero point for photometry estimates [mag]',
#         'name': 'magzpsci',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Magnitude zero point uncertainty (in magzpsci) [mag]',
#         'name': 'magzpsciunc',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'RMS (deviation from average) in all differences between instrumental photometry and matched photometric calibrators from science image processing [mag]',
#         'name': 'magzpscirms',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Color coefficient from linear fit from photometric calibration of science image',
#         'name': 'clrcoeff',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Color coefficient uncertainty from linear fit (corresponding to clrcoeff)',
#         'name': 'clrcounc',
#         'type': ['null', 'float']},
#        {'doc': 'version of RealBogus model/classifier used to assign rb quality score',
#         'name': 'rbversion',
#         'type': 'string'}],
#       'name': 'prv_candidate',
#       'namespace': 'ztf.alert',
#       'type': 'record',
#       'version': '3.3'},
#      'type': 'array'}]},
#   {'default': None,
#    'name': 'cutoutScience',
#    'type': ['null',
#     {'doc': 'avro alert schema',
#      'fields': [{'name': 'fileName', 'type': 'string'},
#       {'doc': 'fits.gz', 'name': 'stampData', 'type': 'bytes'}],
#      'name': 'cutout',
#      'namespace': 'ztf.alert',
#      'type': 'record',
#      'version': '3.3'}]},
#   {'default': None,
#    'name': 'cutoutTemplate',
#    'type': ['null', 'ztf.alert.cutout']},
#   {'default': None,
#    'name': 'cutoutDifference',
#    'type': ['null', 'ztf.alert.cutout']}],
#  'name': 'ztf.alert',
#  'type': 'record',
#  'version': '3.3'}

# %% [markdown]
# Once we have the packet in python data structures our downstream processing should be independent of how we got the packet (from files or from a Kafka stream).

# %% [markdown]
# ### Playing with packet contents

# %% [markdown]
# Once these are in memory they are just a python dictionary, so the top-level attributes are easy to access.

# %%
type(packet)
# Out:
# dict

# %%
packet
# Out:
# {'schemavsn': '3.3',
#  'publisher': 'ZTF (www.ztf.caltech.edu)',
#  'objectId': 'ZTF20acpgdsq',
#  'candid': 1405470501015015011,
#  'candidate': {'jd': 2459159.9705093,
#   'fid': 2,
#   'pid': 1405470501015,
#   'diffmaglim': 20.106834411621094,
#   'pdiffimfilename': 'ztf_20201106470509_000813_zr_c03_o_q3_scimrefdiffimg.fits',
#   'programpi': 'Kulkarni',
#   'programid': 1,
#   'candid': 1405470501015015011,
#   'isdiffpos': 't',
#   'tblid': 11,
#   'nid': 1405,
#   'rcid': 10,
#   'field': 813,
#   'xpos': 1004.60791015625,
#   'ypos': 2427.73046875,
#   'ra': 97.7778457,
#   'dec': 58.5764091,
#   'magpsf': 19.959449768066406,
#   'sigmapsf': 0.2149713784456253,
#   'chipsf': 1.822272539138794,
#   'magap': 19.767200469970703,
#   'sigmagap': 0.29660001397132874,
#   'distnr': 11.045767784118652,
#   'magnr': 22.618000030517578,
#   'sigmagnr': 0.32499998807907104,
#   'chinr': 0.8140000104904175,
#   'sharpnr': -0.31200000643730164,
#   'sky': 0.6024903059005737,
#   'magdiff': -0.19224999845027924,
#   'fwhm': 2.869999885559082,
#   'classtar': 0.9980000257492065,
#   'mindtoedge': 652.7694702148438,
#   'magfromlim': 0.3396335542201996,
#   'seeratio': 0.8371389508247375,
#   'aimage': 0.6230000257492065,
#   'bimage': 0.44699999690055847,
#   'aimagerat': 0.21707317233085632,
#   'bimagerat': 0.1557491272687912,
#   'elong': 1.3937360048294067,
#   'nneg': 8,
#   'nbad': 0,
#   'rb': 0.2328571379184723,
#   'ssdistnr': -999.0,
#   'ssmagnr': -999.0,
#   'ssnamenr': 'null',
#   'sumrat': 0.8651314973831177,
#   'magapbig': 19.661800384521484,
#   'sigmagapbig': 0.3456000089645386,
#   'ranr': 97.7741761,
#   'decnr': 58.5788587,
#   'sgmag1': -999.0,
#   'srmag1': -999.0,
#   'simag1': 21.453899383544922,
#   'szmag1': 21.041099548339844,
#   'sgscore1': 0.3675000071525574,
#   'distpsnr1': 16.596878051757812,
#   'ndethist': 1,
#   'ncovhist': 1483,
#   'jdstarthist': 2459159.9705093,
#   'jdendhist': 2459159.9705093,
#   'scorr': 9.87444496154785,
#   'tooflag': 0,
#   'objectidps1': 178290977817487446,
#   'objectidps2': 178280977877639922,
#   'sgmag2': 17.52739906311035,
#   'srmag2': 17.141700744628906,
#   'simag2': 16.989299774169922,
#   'szmag2': 16.954700469970703,
#   'sgscore2': 1.0,
#   'distpsnr2': 20.053342819213867,
#   'objectidps3': 178280977736894585,
#   'sgmag3': -999.0,
#   'srmag3': 21.51219940185547,
#   'simag3': 21.194700241088867,
#   'szmag3': 21.136600494384766,
#   'sgscore3': 0.06880649924278259,
#   'distpsnr3': 24.577003479003906,
#   'nmtchps': 5,
#   'rfid': 813120210,
#   'jdstartref': 2458160.72919,
#   'jdendref': 2458367.007859,
#   'nframesref': 15,
#   'rbversion': 't17_f5_c3',
#   'dsnrms': 6.8645830154418945,
#   'ssnrms': 12.043331146240234,
#   'dsdiff': -5.17874813079834,
#   'magzpsci': 26.257450103759766,
#   'magzpsciunc': 2.4026999199122656e-06,
#   'magzpscirms': 0.03299599885940552,
#   'nmatches': 1691,
#   'clrcoeff': 0.08113899827003479,
#   'clrcounc': 4.72169995191507e-06,
#   'zpclrcov': -3.11000007968687e-06,
#   'zpmed': 26.308000564575195,
#   'clrmed': 0.5720000267028809,
#   'clrrms': 0.2733739912509918,
#   'neargaia': 20.051233291625977,
#   'neargaiabright': -999.0,
#   'maggaia': 17.08220863342285,
#   'maggaiabright': -999.0,
#   'exptime': 30.0,
#   'drb': 0.15171736478805542,
#   'drbversion': 'd6_m7'},
#  'prv_candidates': [{'jd': 2459129.9877431,
#    'fid': 2,
#    'pid': 1375487741015,
#    'diffmaglim': 20.088300704956055,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1007/487732/ztf_20201007487732_000813_zr_c03_o_q3_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1375,
#    'rcid': 10,
#    'field': 813,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.20560073852539,
#    'magzpsciunc': 2.0742400010931306e-06,
#    'magzpscirms': 0.022672200575470924,
#    'clrcoeff': 0.08558610081672668,
#    'clrcounc': 4.118900051253149e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459129.9910764,
#    'fid': 2,
#    'pid': 1375491074915,
#    'diffmaglim': 20.13520050048828,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1007/491076/ztf_20201007491076_000781_zr_c13_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1375,
#    'rcid': 49,
#    'field': 781,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.19569969177246,
#    'magzpsciunc': 2.3846000658522826e-06,
#    'magzpscirms': 0.024023499339818954,
#    'clrcoeff': 0.079510897397995,
#    'clrcounc': 4.765080120705534e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459131.8557523,
#    'fid': 1,
#    'pid': 1377355751015,
#    'diffmaglim': 19.235200881958008,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1009/355741/ztf_20201009355741_000813_zg_c03_o_q3_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1377,
#    'rcid': 10,
#    'field': 813,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 25.95680046081543,
#    'magzpsciunc': 1.0086600013892166e-05,
#    'magzpscirms': 0.04076889902353287,
#    'clrcoeff': -0.06865990161895752,
#    'clrcounc': 2.571219920355361e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459131.8808796,
#    'fid': 1,
#    'pid': 1377380874915,
#    'diffmaglim': 18.863100051879883,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1009/380868/ztf_20201009380868_000781_zg_c13_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1377,
#    'rcid': 49,
#    'field': 781,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 25.654600143432617,
#    'magzpsciunc': 1.6592899555689655e-05,
#    'magzpscirms': 0.04293059930205345,
#    'clrcoeff': -0.034102000296115875,
#    'clrcounc': 4.790310049429536e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459135.9081944,
#    'fid': 2,
#    'pid': 1381408194915,
#    'diffmaglim': 20.509000778198242,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1013/408194/ztf_20201013408194_000781_zr_c13_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1381,
#    'rcid': 49,
#    'field': 781,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.154300689697266,
#    'magzpsciunc': 2.921819941548165e-06,
#    'magzpscirms': 0.02666120044887066,
#    'clrcoeff': 0.07446960359811783,
#    'clrcounc': 5.773909833806101e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459135.9095949,
#    'fid': 2,
#    'pid': 1381409591015,
#    'diffmaglim': 20.441099166870117,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1013/409595/ztf_20201013409595_000813_zr_c03_o_q3_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 

#    'rcid': 49,
#    'field': 781,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 25.780099868774414,
#    'magzpsciunc': 3.305910013295943e-06,
#    'magzpscirms': 0.028406500816345215,
#    'clrcoeff': 0.07336200028657913,
#    'clrcounc': 6.538819889101433e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459141.8900463,
#    'fid': 2,
#    'pid': 1387390041015,
#    'diffmaglim': 19.26849937438965,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1019/390046/ztf_20201019390046_000813_zr_c03_o_q3_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1387,
#    'rcid': 10,
#    'field': 813,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 25.482900619506836,
#    'magzpsciunc': 7.112740149750607e-06,
#    'magzpscirms': 0.04214470088481903,
#    'clrcoeff': 0.08384110033512115,
#    'clrcounc': 1.4082499546930194e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459141.9344097,
#    'fid': 1,
#    'pid': 1387434401015,
#    'diffmaglim': 20.4773006439209,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1019/434363/ztf_20201019434363_000813_zg_c03_o_q3_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1387,
#    'rcid': 10,
#    'field': 813,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.22279930114746,
#    'magzpsciunc': 3.759540049941279e-06,
#    'magzpscirms': 0.030605999752879143,
#    'clrcoeff': -0.11401200294494629,
#    'clrcounc': 7.430150162690552e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459141.946794,
#    'fid': 1,
#    'pid': 1387446794915,
#    'diffmaglim': 20.858999252319336,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1019/446794/ztf_20201019446794_000781_zg_c13_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1387,
#    'rcid': 49,
#    'field': 781,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.25790023803711,
#    'magzpsciunc': 1.250710010936018e-05,
#    'magzpscirms': 0.05493269860744476,
#    'clrcoeff': -0.14475299417972565,
#    'clrcounc': 2.5013299818965606e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459143.9122685,
#    'fid': 1,
#    'pid': 1389412264915,
#    'diffmaglim': 20.9606990814209,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1021/412222/ztf_20201021412222_000781_zg_c13_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1389,
#    'rcid': 49,
#    'field': 781,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.26110076904297,
#    'magzpsciunc': 1.4332599675981328e-05,
#    'magzpscirms': 0.0590474009513855,
#    'clrcoeff': -0.1523510068655014,
#    'clrcounc': 2.851960016414523e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459143.9266435,
#    'fid': 1,
#    'pid': 1389426641015,
#    'diffmaglim': 20.844600677490234,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1021/426632/ztf_20201021426632_000813_zg_c03_o_q3_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1389,
#    'rcid': 10,
#    'field': 813,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.359699249267578,
#    'magzpsciunc': 2.283509957123897e-06,
#    'magzpscirms': 0.02383360080420971,
#    'clrcoeff': -0.11458200216293335,
#    'clrcounc': 4.468589850148419e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459143.9479977,
#    'fid': 2,
#    'pid': 1389447994915,
#    'diffmaglim': 20.67530059814453,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1021/447975/ztf_20201021447975_000781_zr_c13_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1389,
#    'rcid': 49,
#    'field': 781,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.178600311279297,
#    'magzpsciunc': 4.023409928777255e-06,
#    'magzpscirms': 0.03130539879202843,
#    'clrcoeff': 0.06888800114393234,
#    'clrcounc': 8.013929800654296e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459143.9686227,
#    'fid': 2,
#    'pid': 1389468621015,
#    'diffmaglim': 20.56089973449707,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1021/468611/ztf_20201021468611_000813_zr_c03_o_q3_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1389,
#    'rcid': 10,
#    'field': 813,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.215599060058594,
#    'magzpsciunc': 1.4681199900223874e-06,
#    'magzpscirms': 0.01900229975581169,
#    'clrcoeff': 0.08739680051803589,
#    'clrcounc': 2.9014499887125567e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459145.8609722,
#    'fid': 2,
#    'pid': 1391360971015,
#    'diffmaglim': 20.510700225830078,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1023/360972/ztf_20201023360972_000813_zr_c03_o_q3_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1391,
#    'rcid': 10,
#    'field': 813,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.191600799560547,
#    'magzpsciunc': 1.345949954156822e-06,
#    'magzpscirms': 0.018222199752926826,
#    'clrcoeff': 0.08332639932632446,
#    'clrcounc': 2.661620101207518e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459145.8867477,
#    'fid': 2,
#    'pid': 1391386744915,
#    'diffmaglim': 20.648099899291992,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1023/386748/ztf_20201023386748_000781_zr_c13_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1391,
#    'rcid': 49,
#    'field': 781,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.16029930114746,
#    'magzpsciunc': 3.7108400192664703e-06,
#    'magzpscirms': 0.030099499970674515,
#    'clrcoeff': 0.06893250346183777,
#    'clrcounc': 7.405049927911023e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459145.93625,
#    'fid': 1,
#    'pid': 1391436244915,
#    'diffmaglim': 20.80190086364746,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1023/436204/ztf_20201023436204_000781_zg_c13_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1391,
#    'rcid': 49,
#    'field': 781,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.199499130249023,
#    'magzpsciunc': 1.9670100300572813e-05,
#    'magzpscirms': 0.06896690279245377,
#    'clrcoeff': -0.16551899909973145,
#    'clrcounc': 3.94175986002665e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459145.936713,
#    'fid': 1,
#    'pid': 1391436711015,
#    'diffmaglim': 20.765399932861328,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1023/436713/ztf_20201023436713_000813_zg_c03_o_q3_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1391,
#    'rcid': 10,
#    'field': 813,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.296199798583984,
#    'magzpsciunc': 2.880449983422295e-06,
#    'magzpscirms': 0.02682190015912056,
#    'clrcoeff': -0.11327599734067917,
#    'clrcounc': 5.6724497881077696e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459149.9264352,
#    'fid': 2,
#    'pid': 1395426434915,
#    'diffmaglim': 19.881200790405273,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1027/426435/ztf_20201027426435_000781_zr_c13_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1395,
#    'rcid': 49,
#    'field': 781,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.16230010986328,
#    'magzpsciunc': 2.789960035443073e-06,
#    'magzpscirms': 0.02592349983751774,
#    'clrcoeff': 0.07371260225772858,
#    'clrcounc': 5.54034977540141e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459149.9268981,
#    'fid': 2,
#    'pid': 1395426891015,
#    'diffmaglim': 20.034099578857422,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1027/426898/ztf_20201027426898_000813_zr_c03_o_q3_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1395,
#    'rcid': 10,
#    'field': 813,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.193700790405273,
#    'magzpsciunc': 1.963539943972137e-06,
#    'magzpscirms': 0.02210419997572899,
#    'clrcoeff': 0.08361390233039856,
#    'clrcounc': 3.889750132657355e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459149.9860995,
#    'fid': 1,
#    'pid': 1395486091015,
#    'diffmaglim': 20.383399963378906,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1027/486076/ztf_20201027486076_000813_zg_c03_o_q3_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1395,
#    'rcid': 10,
#    'field': 813,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.343299865722656,
#    'magzpsciunc': 3.642169986051158e-06,
#    'magzpscirms': 0.030060799792408943,
#    'clrcoeff': -0.09590180218219757,
#    'clrcounc': 7.286129857675405e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459149.9865625,
#    'fid': 1,
#    'pid': 1395486564915,
#    'diffmaglim': 20.32270050048828,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1027/486562/ztf_20201027486562_000781_zg_c13_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1395,
#    'rcid': 49,
#    'field': 781,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.25480079650879,
#    'magzpsciunc': 8.80466996022733e-06,
#    'magzpscirms': 0.04508129879832268,
#    'clrcoeff': -0.09730289876461029,
#    'clrcounc': 1.8075399566441774e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459151.8608912,
#    'fid': 2,
#    'pid': 1397360891015,
#    'diffmaglim': 19.794099807739258,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1029/360856/ztf_20201029360856_000813_zr_c03_o_q3_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1397,
#    'rcid': 10,
#    'field': 813,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.24139976501465,
#    'magzpsciunc': 2.3880900243966607e-06,
#    'magzpscirms': 0.024368299171328545,
#    'clrcoeff': 0.09068790078163147,
#    'clrcounc': 4.722419816971524e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459151.8903356,
#    'fid': 1,
#    'pid': 1397390334915,
#    'diffmaglim': 19.517099380493164,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1029/390313/ztf_20201029390313_000781_zg_c13_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1397,
#    'rcid': 49,
#    'field': 781,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.320199966430664,
#    'magzpsciunc': 1.0276299690303858e-05,
#    'magzpscirms': 0.04212170094251633,
#    'clrcoeff': -0.03943739831447601,
#    'clrcounc': 2.5870900572044775e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2459151.8907986,
#    'fid': 1,
#    'pid': 1397390791015,
#    'diffmaglim': 19.540599822998047,
#    'pdiffimfilename': '/ztf/archive/sci/2020/1029/390799/ztf_20201029390799_000813_zg_c03_o_q3_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1397,
#    'rcid': 10,
#    'field': 813,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.37529945373535,
#    'magzpsciunc': 9.414269698027056e-06,
#    'magzpscirms': 0.04156149923801422,
#    'clrcoeff': -0.05388209968805313,
#    'clrcounc': 2.314529956493061e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2
87\x19\xefZ@G\x03\xa7@\xca\xaaD\xae\xdej\x119\xac5`&K\x0e\x80\\\x83\x13\xc4_~BQ\xfa\x99\xfc\x81\x8fs\xe1\xb1\xd2#\xb4\x96\x18\xe0\xaeV\xef\xa0\x8d\xcf\xc7\xa1\x9d\xe6\x00\x86\xec\x1b\xcd\x1d<\xf7\x9c\x89\x9fp%\xd3\x97u\\\xe1\xa7s|\xa8\xc5o\x9av#\x02\xca\xe6\x06\xc1\x8c\xbd/`\x9a\xa7\x08]\x8b\xbcD\xef\xdcZ\xe9Q\xcc(\x16a0\x99\n\xdd\xccp^\xf2Djz\xaa\x8b\x82\x1b\xf3i\xbc\xf4\n\x1a\xb1\x10`\xa1\xe4\'~k\xaa\x06\x9b!1\x95\xb9\xe4\xbc\x83\x87zC0\xd2\xe8\x17Z\xdd\x14\xc5\x99\xce\xe1d\xe3\xac\xc6\xa5/\xed\x83\xbac\xb7X\xc1\xd0\xef4\xdd\x9bc\xe2j\x0b\xd8\xec\xef>\xd4f\x93H\xafDk\x98T\x968q\xa7\xee\x93\xfcro\x8a~\xfe\x89\x93\xf5yc\x9dq;\x13\xd3\x15\xf4`A\x95\x0e\x1d\x9bh\x86\xb1G\x9e\xe0\x8a\xb2b\xa6\x1b\xad\xc7P \x05\rn_\xa0^-\x9b\x8b\x1a\xf9\x12\xcc\r\xcch\xf2\xf2\xbb\xb4\xfd\xde_\xd4\x0e=\x01\x1d\xd7\x8f\xb1\xb5\x01K\x04\x15"\x1a8t\xfa3\x88\xba\xdc\x82J\x81\x89|\xda\xe5+L\xd5y?\xa7\xc3\xf53?\xed8\xd2z\xdb\x8a#\xc7\xb625\xdf}\xb0\xb6\xcc\x13\x87\x184A\xd4<y\x9a\xeep\x8e\xff\x0b\xc6\x90\x99\xe1@\xd9\rN\xb ...

# %%
print('JD: {} Filter: {} Mag: {:.2f}+/-{:.2f}'.format(
    packet['candidate']['jd'],packet['candidate']['fid'],
    packet['candidate']['magpsf'],packet['candidate']['sigmapsf']))
# Out:
# JD: 2459159.9705093 Filter: 2 Mag: 19.96+/-0.21

# %% [markdown]
# **NOTE ESPECIALLY**: the magnitudes here do not include the magnitude of the underlying reference source (if present), so if this is a variable star further adjustment is needed.  Example to come...

# %% [markdown]
# Record access like this is a little verbose; let's wrap things up in a dataframe for ease of access (and faster loading).

# %% [markdown]
# Now let's extract the lightcurves.  The alert packet formats are nested, so the historical detections (if present) have the same structure as the candidate triggering the alert (minus a couple fields).

# %%
def make_dataframe(packet):
    df = pd.DataFrame(packet['candidate'], index=[0])
    df_prv = pd.DataFrame(packet['prv_candidates'])
    return pd.concat([df,df_prv], ignore_index=True)

# %%
dflc = make_dataframe(packet)
dflc
# Out:
#               jd  fid            pid  diffmaglim  \
# 0   2.459160e+06    2  1405470501015   20.106834
# 1   2.459130e+06    2  1375487741015   20.088301
# 2   2.459130e+06    2  1375491074915   20.135201
# 3   2.459132e+06    1  1377355751015   19.235201
# 4   2.459132e+06    1  1377380874915   18.863100
# 5   2.459136e+06    2  1381408194915   20.509001
# 10        NaN            NaN        NaN           NaN     NaN       NaN
# 11        NaN            NaN        NaN           NaN     NaN       NaN
# 12        NaN            NaN        NaN           NaN     NaN       NaN
# 13        NaN            NaN        NaN           NaN     NaN       NaN
# 14        NaN            NaN        NaN           NaN     NaN       NaN
# 15        NaN            NaN        NaN           NaN     NaN       NaN
# 16        NaN            NaN        NaN           NaN     NaN       NaN
# 17        NaN            NaN        NaN           NaN     NaN       NaN
# 18        NaN            NaN        NaN           NaN     NaN       NaN
# 19        NaN            NaN        NaN           NaN     NaN       NaN
# 20        NaN            NaN        NaN           NaN     NaN       NaN
# 21        NaN            NaN        NaN           NaN     NaN       NaN
# 22        NaN            NaN        NaN           NaN     NaN       NaN
# 23        NaN            NaN        NaN           NaN     NaN       NaN
# 24        NaN            NaN        NaN           NaN     NaN       NaN
# 25        NaN            NaN        NaN           NaN     NaN       NaN
# 26        NaN            NaN        NaN           NaN     NaN       NaN
# 27        NaN            NaN        NaN           NaN     NaN       NaN
# 28        NaN            NaN        NaN           NaN     NaN       NaN
# 29        NaN            NaN        NaN           NaN     NaN       NaN
# 30        NaN            NaN        NaN           NaN     NaN       NaN
# 31        NaN            NaN        NaN           NaN     NaN       NaN
# 32        NaN            NaN        NaN           NaN     NaN       NaN
# 33        NaN            NaN        NaN           NaN     NaN       NaN
# 34        NaN            NaN        NaN           NaN     NaN       NaN
# 35        NaN            NaN        NaN           NaN     NaN       NaN
# 36        NaN            NaN        NaN           NaN     NaN       NaN
# 37        NaN            NaN        NaN           NaN     NaN       NaN
# 38        NaN            NaN        NaN           NaN     NaN       NaN
# 39        NaN            NaN        NaN           NaN     NaN       NaN
# 40        NaN            NaN        NaN           NaN     NaN       NaN
# 41        NaN            NaN        NaN           NaN     NaN       NaN
# 42        NaN            NaN        NaN           NaN     NaN       NaN
# 43        NaN            NaN        NaN           NaN     NaN       NaN
# 44        NaN            NaN        NaN           NaN     NaN       NaN
# 45        NaN            NaN        NaN           NaN     NaN       NaN
# 46        NaN            NaN        NaN           NaN     NaN       NaN
#
#    drbversion
# 0       d6_m7
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# 30        NaN
# 31        NaN
# 32        NaN
# 33        NaN
# 34        NaN
# 35        NaN
# 36        NaN
# 37        NaN
# 38        NaN
# 39        NaN
# 40        NaN
# 41        NaN
# 42        NaN
# 43        NaN
# 44        NaN
# 45        NaN
# 46        NaN
#
# [47 rows x 103 columns]

# %%
dflc.columns
# Out:
# Index(['jd', 'fid', 'pid', 'diffmaglim', 'pdiffimfilename', 'programpi',
#        'programid', 'candid', 'isdiffpos', 'tblid',
#        ...
#        'zpmed', 'clrmed', 'clrrms', 'neargaia', 'neargaiabright', 'maggaia',
#        'maggaiabright', 'exptime', 'drb', 'drbversion'],
#       dtype='object', length=103)

# %% [markdown]
# We see that some of the historical detections are upper limits, signified by the NaNs.  Note that the most recent candidate has a few fields that are not present for the `prv_candidates`.
#
# Let's plot it!

# %%
def plot_lightcurve(dflc, days_ago=True):
    
    filter_color = {1:'green', 2:'red', 3:'pink'}
    if days_ago:
        now = Time.now().jd
        t = dflc.jd - now
        xlabel = 'Days Ago'
    else:
        t = dflc.jd
        xlabel = 'Time (JD)'
    
    plt.figure()
    for fid, color in filter_color.items():
        # plot detections in this filter:
        w = (dflc.fid == fid) & ~dflc.magpsf.isnull()
        if np.sum(w):
\xd2\xda\r \xb6d6Y\'\xcaa\x15\xedC\xce\xee\xba\xf8S\x07b\x16\xbe\x86w\xb0<\xe6\xb6\xe2\x84v\xce\xc5\\\x94Jx\xbfK,\x96\x97P\xfe\xb2X\x8d\x8b\xe0\xb4\x1f\x88\xfd\xe9*\xc2\x86f-\xd2\x04\xf3\x9dm\xd8\xf3=\x82;\xab\xe0N~\x05\xfb\xefE$>\xe8\x84\xf3\xfe\xf7X\xdb\xceb\xfcv\x93\xd5\x85wcvx\x11\xdfm\x883_\xba\xf1\xf4Q\xac>\xa3\x08\xc6T\xc4\\\xd1\x04#\x7f\x12\xf7\x91A$k\xcf\xc5\x9dW\x90\xe4\xfa\x92\xaa})\x9c:U\x89\xdc)-(V\x19s\x90\x8d\xd7s\x11\xde/\xd7\xc98\xae\xe7\x7f\xd8\xc6\x9f\x9b\x87\xc8\xa5\xbad\xd6\x9b\x81]\xa5\x08\xb1\xad\xaa\xf1\x88t\x8c\x1c\x9d\xf9\xd1U\xf8[\xe7\xe3\x15+G\xda=5\x88\xd6=\x85Ws=\xc9\x8b\x8b\xb1rmB\x95o\xb1\xea\xa9\n8\x1fN\xc5?\xbbM\xf7\xae\x8fym7F\xb9\xba\x18)\xea\xd7\x05\xe9E\xb0\x0f\xab\xfbf\xdc}\x05\t\x97\xd8@tk_\xbc\xf7*\x13m>\x14\xf3\xeeN\xc4J<\xae\xf7~\x8d\x9b\x11\'\xdei\x18v\xe9m\x04\x05\xfa\x91\x98\xde\x15\xa3zw\xacg\xaf\xe1\x0f\xb4HN\xeb\x8f\x9b\xab{\x8e\xf9\x9a\xe8;\xcdq\x9b&q\x1a\xb9x\xe9M\x ...

# %%
stamp = packet['cutoutScience']['stampData']

# %%
type(stamp)
# Out:
# bytes

# %%
def plot_cutout(stamp, fig=None, subplot=None, **kwargs):
    with gzip.open(io.BytesIO(stamp), 'rb') as f:
        with fits.open(io.BytesIO(f.read())) as hdul:
            if fig is None:
                fig = plt.figure(figsize=(4,4))
            if subplot is None:
                subplot = (1,1,1)
            ffig = aplpy.FITSFigure(hdul[0],figure=fig, subplot=subplot, **kwargs)
            ffig.show_grayscale(stretch='power')
    return ffig

# %%
plot_cutout(stamp)
# Out:
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to  3.193e+02 [aplpy.core]
# INFO: Auto-setting vmax to  5.415e+02 [aplpy.core]

# %% [markdown]
# Now let's make a nice helper function:

# %%
def show_stamps(packet):
    #fig, axes = plt.subplots(1,3, figsize=(12,4))
    fig = plt.figure(figsize=(12,4))
    for i, cutout in enumerate(['Science','Template','Difference']):
        stamp = packet['cutout{}'.format(cutout)]['stampData']
        ffig = plot_cutout(stamp, fig=fig, subplot = (1,3,i+1))
        ffig.set_title(cutout)

# %%
show_stamps(packet)
# Out:
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to  3.193e+02 [aplpy.core]
# INFO: Auto-setting vmax to  5.415e+02 [aplpy.core]
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to  3.409e+02 [aplpy.core]
# INFO: Auto-setting vmax to  6.379e+02 [aplpy.core]
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# INFO: Auto-setting vmin to -3.106e+01 [aplpy.core]
# INFO: Auto-setting vmax to  4.828e+01 [aplpy.core]
